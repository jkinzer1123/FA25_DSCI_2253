# %% [markdown]
# The first thing we are going to want to do, is create a code cell block and import pandas and matplotlib.pyplot. Add a code cell below and write code to import those two packages and execute.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# The next thing we are going to do is pull in our dataframe. Be sure that you have the Restaurant_Sales.csv file in your same file folder that you have this notebook in. Add a code block and write the code to import your .csv and execute.
#
# Hint: because we are importing a .csv file instead of a .tsv you don't need the "sep = " parameter, because .read_csv() uses sep = ',' automatically.

# %%
df = pd.read_csv('Restaurant_Sales.csv', sep=',')  # Ensure the correct separator is used for CSV files

# %% [markdown]
# Next, lets take a look at the dataframe we just pulled into our notebook. Create and run 4 different code blocks, each with a different method that lets you view your data.

# %%
df.head()
# Out:
#    Order ID        Date             Product  Price  Quantity Purchase Type  \
# 0     10452  07-11-2022               Fries   3.49    573.07       Online
# 1     10453  07-11-2022           Beverages   2.95    745.76       Online
# 2     10454  07-11-2022       Sides & Other   4.99    200.40     In-store
# 3     10455  08-11-2022             Burgers  12.99    569.67     In-store
# 4     10456  08-11-2022  Chicken Sandwiches   9.95    201.01     In-store
#
#   Payment Method             Manager    City
# 0      Gift Card    Tom      Jackson  London
# 1      Gift Card         Pablo Perez  Madrid
# 2      Gift Card       Joao    Silva  Lisbon
# 3    Credit Card       Walter Muller  Berlin
# 4    Credit Card       Walter Muller  Berlin

# %%
df.tail()
# Out:
#      Order ID        Date             Product  Price  Quantity Purchase Type  \
# 249     10709  28-12-2022       Sides & Other   4.99    200.40   Drive-thru
# 250     10710  29-12-2022             Burgers  12.99    754.43   Drive-thru
# 251     10711  29-12-2022  Chicken Sandwiches   9.95    281.41   Drive-thru
# 252     10712  29-12-2022               Fries   3.49    630.37   Drive-thru
# 253     10713  29-12-2022           Beverages   2.95    677.97   Drive-thru
#
#     Payment Method        Manager    City
# 249      Gift Card  Walter Muller  Berlin
# 250      Gift Card  Walter Muller  Berlin
# 251      Gift Card  Walter Muller  Berlin
# 252      Gift Card  Walter Muller  Berlin
# 253      Gift Card  Walter Muller  Berlin

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 0 to 253
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        254 non-null    int64
#  1   Date            254 non-null    object
#  2   Product         254 non-null    object
#  3   Price           254 non-null    float64
#  4   Quantity        254 non-null    float64
#  5   Purchase Type   254 non-null    object
#  6   Payment Method  254 non-null    object
#  7   Manager         254 non-null    object
#  8   City            254 non-null    object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 18.0+ KB

# %%
df.shape
# Out:
# (254, 9)

# %% [markdown]
# Now that we have checked out our dataframe, lets do some subsetting. For this section, do the following:
#
# 1) Subset the dataframe by creating a reference variable "sub_1_df" and create a new series from just the Price column. Display this new series using .head()
#
# 2) Subset the dataframe by creating a reference variable "sub_2_df" and create a new dataframe from the Product, Price, and City columns. Display this new dataframe using .head()
#
# 3) Subset the dataframe by creating a reference variable "sub_3_df" and create a new dataframe from the Product, Price, and City columns, and subset to only the last 10 rows. Display this new dataframe using .head()
#
# 4) Use .loc to display the first row of the "sub_3_df" dataframe.
#
# 5) Use .iloc to display the first row of the "sub_3_df" dataframe.
#
# Be sure to accomplish each of these in a separate code cell.

# %%
sub_1_df = df['Price']

sub_1_df.head()
# Out:
# 0     3.49
# 1     2.95
# 2     4.99
# 3    12.99
# 4     9.95
# Name: Price, dtype: float64

# %%
sub_2_df = df[['Product', 'Price', 'City']]

sub_2_df.head()
# Out:
#               Product  Price    City
# 0               Fries   3.49  London
# 1           Beverages   2.95  Madrid
# 2       Sides & Other   4.99  Lisbon
# 3             Burgers  12.99  Berlin
# 4  Chicken Sandwiches   9.95  Berlin

# %%
sub_3_df = df.iloc[-10::1, [2, 3, 7]]

sub_3_df.head(10)
# Out:
#                 Product  Price        Manager
# 244       Sides & Other   4.99  Walter Muller
# 245             Burgers  12.99  Walter Muller
# 246  Chicken Sandwiches   9.95  Walter Muller
# 247               Fries   3.49  Walter Muller
# 248           Beverages   2.95  Walter Muller
# 249       Sides & Other   4.99  Walter Muller
# 250             Burgers  12.99  Walter Muller
# 251  Chicken Sandwiches   9.95  Walter Muller
# 252               Fries   3.49  Walter Muller
# 253           Beverages   2.95  Walter Muller

# %% [markdown]
# Next we will want to group our dataframe and calculate some averages. Group your original dataframe (not a subset) by Product and City. Then calculate the average Price and Quantity and flatten the table.

# %%
(df
    .groupby(['Product', 'City'])[['Price', 'Quantity']]
    .mean()
    .reset_index()
)
# Out:
#                Product    City      Price    Quantity
# 0            Beverages  Berlin   2.950000  677.970000
# 1            Beverages  Lisbon   2.950000  711.865000
# 2            Beverages  London   2.950000  697.338571
# 3            Beverages  Madrid   2.950000  693.034444
# 4            Beverages   Paris   2.950000  705.086000
# 5              Burgers  Berlin  12.990000  685.141667
# 6              Burgers  Lisbon  12.990000  598.261429
# 7              Burgers  London  12.990000  522.454667
# 8              Burgers  Madrid  12.990000  515.080000
# 9              Burgers   Paris  12.990000  505.516667
# 10  Chicken Sandwiches  Berlin   9.950000  268.010000
# 11  Chicken Sandwiches  Lisbon  11.223333  219.770000
# 12  Chicken Sandwiches  London   9.950000  201.010000
# 13  Chicken Sandwiches  Madrid   9.950000  201.010000
# 14  Chicken Sandwiches   Paris   9.950000  201.010000
# 15               Fries  Berlin   3.490000  630.370000
# 16               Fries  Lisbon   4.957333  645.652667
# 17               Fries  London   3.490000  619.626250
# 18               Fries  Madrid   3.490000  616.046250
# 19               Fries   Paris   3.490000  620.823333
# 20       Sides & Other  Berlin   4.990000  200.400000
# 21       Sides & Other  Lisbon   4.990000  200.400000
# 22       Sides & Other  London   4.990000  200.400000
# 23       Sides & Other  Madrid   4.990000  200.400000
# 24       Sides & Other   Paris   4.990000  200.400000

# %% [markdown]
# The last thing we are going to do, is populate a simple visual. Use matplotlib.pyplot to create a simple bar graph with Product on the x axis and total quantity on the y axis

# %%
import matplotlib.pyplot as plt
# probably don't need the magic anymore
#%matplotlib inline

(df
     .groupby(['Product'])
     [['Quantity']]
     .sum()
     .plot(kind='bar')
)
plt.show()
